# %%
# 1. Force Jupyter to change its working directory to your repository's path
import os
os.chdir(os.path.expanduser('~/phononwebsite/python/phononweb'))

# 2. Add it to Python's system lookup search paths
import sys
if os.getcwd() not in sys.path:
    sys.path.insert(0, os.getcwd())

# 3. Perform the local file diagnostic import on phonon.py
import inspect

try:
    from phonon import Phonon
    print("--- PHONON.PY CLASS DIAGNOSTIC ---")
    print("1. Confirmed File Location:", inspect.getfile(Phonon))
    print("\n2. All Methods available inside this class:")
    
    # Filter and list only the functions/methods defined inside the Phonon class
    methods = [name for name, val in inspect.getmembers(Phonon, predicate=inspect.isfunction)]
    for method in sorted(methods):
        print(f"   - {method}()")
        
    print("\n3. Checking for chirality method mapping:")
    print("   Is 'compute_chiral_properties' a method of Phonon?:", hasattr(Phonon, 'compute_chiral_properties'))

except ImportError as e:
    print("--- DIAGNOSTIC ERROR ---")
    print(f"Could not import Phonon from phonon.py. Reason: {e}")
# Out:
# --- DIAGNOSTIC ERROR ---
# Could not import Phonon from phonon.py. Reason: No module named 'phononweb'

# %%
# 1. Force Jupyter to step back out to the parent 'python' folder
import os
os.chdir(os.path.expanduser('~/phononwebsite/python'))

# 2. Add this parent directory to Python's system search path
import sys
if os.getcwd() not in sys.path:
    sys.path.insert(0, os.getcwd())

# 3. Import from the explicit package layout
import inspect

try:
    # Explicitly target the module inside the package namespace
    from phononweb.phonon import Phonon
    print("--- PHONON.PY CLASS DIAGNOSTIC ---")
    print("1. Confirmed File Location:", inspect.getfile(Phonon))
    print("\n2. All Methods available inside this class:")
    
    # Filter and list only the functions/methods defined inside the Phonon class
    methods = [name for name, val in inspect.getmembers(Phonon, predicate=inspect.isfunction)]
    for method in sorted(methods):
        print(f"   - {method}()")
        
    print("\n3. Checking for chirality method mapping:")
    print("   Is 'compute_chiral_properties' a method of Phonon?:", hasattr(Phonon, 'compute_chiral_properties'))

except ImportError as e:
    print("--- DIAGNOSTIC ERROR ---")
    print(f"Failed to import Phonon. Reason: {e}")
# Out:
# --- DIAGNOSTIC ERROR ---
# Failed to import Phonon. Reason: No module named 'phonopy'

# %%
# 1. Force Jupyter to step back out to the parent 'python' folder
import os
os.chdir(os.path.expanduser('~/phononwebsite/python'))

# 2. Add this parent directory to Python's system search path
import sys
if os.getcwd() not in sys.path:
    sys.path.insert(0, os.getcwd())

# 3. Import from the explicit package layout
import inspect

try:
    # Target the base class from the package namespace
    from phononweb.phonon import Phonon
    print("--- PHONON.PY CLASS DIAGNOSTIC ---")
    print("1. Confirmed File Location:", inspect.getfile(Phonon))
    
    print("\n2. All Methods available inside this class:")
    # Filter and list only the functions/methods defined inside the Phonon class
    methods = [name for name, val in inspect.getmembers(Phonon, predicate=inspect.isfunction)]
    for method in sorted(methods):
        print(f"   - {method}()")
        
    print("\n3. Checking for chirality method mapping:")
    print("   Is 'compute_chiral_properties' a method of Phonon?:", hasattr(Phonon, 'compute_chiral_properties'))

except ImportError as e:
    print("--- DIAGNOSTIC ERROR ---")
    print(f"Failed to import Phonon. Reason: {e}")
    print("\n💡 Tip: If it names another missing module, run: pip install <module_name> --user --break-system-packages")
# Out:
# --- PHONON.PY CLASS DIAGNOSTIC ---
# 1. Confirmed File Location: /home/atharvmaheshwari/phononwebsite/python/phononweb/phonon.py
#
# 2. All Methods available inside this class:
#    - __str__()
#    - get_chemical_formula()
#    - get_distances_qpts()
#    - get_highsym_qpts()
#    - open_json()
#    - reorder_eigenvalues()
#    - save_netcdf()
#    - set_labels()
#    - set_repetitions()
#    - write_json()
#
# 3. Checking for chirality method mapping:
#    Is 'compute_chiral_properties' a method of Phonon?: False
